# %%
# import some dependencies

import pandas as pd
import numpy as np
import seaborn as sns
from mlxtend.plotting import plot_decision_regions
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.DataFrame()

# %%
df['x1']=[5,7,3,9,1,2,0,2,6,5]
df['x2']=[1,4,2,5,2,8,0,4,6,7]
df['label']=[0,1,0,0,0,1,1,0,1,1]
df
# Out:
#    x1  x2  label
# 0   5   1      0
# 1   7   4      1
# 2   3   2      0
# 3   9   5      0
# 4   1   2      0
# 5   2   8      1
# 6   0   0      1
# 7   2   4      0
# 8   6   6      1
# 9   5   7      1

# %%
# assign weights

df['weight']= 1/df.shape[0]

# %%
df
# Out:
#    x1  x2  label  weight
# 0   5   1      0     0.1
# 1   7   4      1     0.1
# 2   3   2      0     0.1
# 3   9   5      0     0.1
# 4   1   2      0     0.1
# 5   2   8      1     0.1
# 6   0   0      1     0.1
# 7   2   4      0     0.1
# 8   6   6      1     0.1
# 9   5   7      1     0.1

# %%
# ploting data

sns.scatterplot(data=df, x='x1', y='x2', hue='label')
# Out:
# <Axes: xlabel='x1', ylabel='x2'>

# %%
# extract X and y and fit into all decisiontreeclassifier
X= df.iloc[:,:2].values
y= df.loc[:, 'label'].values

# %%
# decision tree 1

dt1 = DecisionTreeClassifier(max_depth=1)
