# %%
from sklearn.datasets import make_classification
import numpy as np
import matplotlib.pyplot as plt

# %%
x,y = make_classification(n_samples=200, n_features=2, n_informative=1, n_redundant=0,
                         n_classes=2, n_clusters_per_class=1, random_state=41, hypercube=False, class_sep = 10)

# %%
plt.figure(figsize=(10,6))
plt.scatter(x[:,0], x[:,1], c=y, cmap='winter', s=100)
plt.show()

# %%
def perceptron(x,y):
    x= np.insert(x,0,1,axis=1)    # inset a new column at '0' index in x which value is '1'
    weights = np.ones(x.shape[1])  # create a new array
    lr = 0.1
    epochs = 1000

    for i in range(epochs):
        # pick random point 
        j = np.random.randint(0,200)
        # calculating y_hat
        y_hat = step(np.dot(x[j], weights))
        # changing weights
        weights = weights + (lr*(y[j]-y_hat)*x[j])

    return weights[0], weights[1:]

# %%
def step(z):
    return 1 if z>0 else 0

# %%
intercept_, coef_ = perceptron(x,y)

# %%
intercept_
# Out:
# np.float64(0.20000000000000015)

# %%
coef_
# Out:
# array([ 1.50141035, -0.11665408])

# %%
m = -(coef_[0]/coef_[1])
b = -(intercept_/coef_[1])

# %%
x_input = np.linspace(-3,3,100)
y_input = m*x_input +b

# %%
np.dot(x[3], weights)
# Out:
# np.float64(0.7129393519334747)

# %%
x= np.insert(x,0,1,axis=1)    # inset a new column at '0' index in x which value is '1'
weights = np.ones(x.shape[1])

# %%
x[3]
# Out:
# array([ 1.        ,  1.        , -1.29125028,  0.00418963])
