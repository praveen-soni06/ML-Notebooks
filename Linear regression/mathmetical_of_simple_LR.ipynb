# %%
class MeraLR:

    def __init__(self):
        self.m = None
        self.b = None

    def fit(self, x_train, y_train):
        num = 0
        dnum = 0

        for i in range(x_train.shape[0]):
            num += ((y_train[i]-y_train.mean()) * (x_train[i] - x_train.mean()))
            dnum += (x_train[i] - x_train.mean())**2

        self.m = num/dnum
        self.b = (y_train.mean() - (self.m * x_train.mean()))

        print(self.m)
        print(self.b)
        
    def pridict(self, x_test):

        # pridict = mx + b
        return ((self.m * x_test) + self.b)

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
x = df.iloc[:,0].values

# %%
y = df.iloc[:,1].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 2)

# %%
lr = MeraLR()

# %%
lr.fit(x_train, y_train)
# Out:
# 0.5557424096560765
# -0.8781178361812056

# %%
lr.pridict(x_test[0])
# Out:
# np.float64(3.8901520386679307)

# %%
plt.scatter(x_test, y_test)
plt.plot(x_test, lr.pridict(x_test))

# %%
import matplotlib.pyplot as plt
