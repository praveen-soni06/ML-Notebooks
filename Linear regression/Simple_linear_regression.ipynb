# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.sample(5)
# Out:
#      cgpa  package
# 193  4.57     1.94
# 5    7.89     2.99
# 77   8.99     4.60
# 100  7.95     4.14
# 137  7.14     3.13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   cgpa     200 non-null    float64
#  1   package  200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.3 KB

# %%
df.describe()
# Out:
#              cgpa     package
# count  200.000000  200.000000
# mean     6.990500    2.996050
# std      1.069409    0.691644
# min      4.260000    1.370000
# 25%      6.190000    2.487500
# 50%      6.965000    2.995000
# 75%      7.737500    3.492500
# max      9.580000    4.620000

# %%
df.max()
# Out:
# cgpa       9.58
# package    4.62
# dtype: float64

# %%
df.min()
# Out:
# cgpa       4.26
# package    1.37
# dtype: float64

# %%
df.std()
# Out:
# cgpa       1.069409
# package    0.691644
# dtype: float64

# %%
sns.kdeplot(df , x='cgpa', y = 'package', fill = True,color='yellow',alpha = 0.3)
# Out:
# <Axes: xlabel='cgpa', ylabel='package'>

# %%
df.mean()
# Out:
# cgpa       6.99050
# package    2.99605
# dtype: float64

# %%
plt.scatter(df['cgpa'], df['package'])
plt.title("CGAP VS PACKAGE")
plt.xlabel('CGPA')
plt.ylabel("PACKAGE")
plt.show()

# %%
x = df.iloc[:,0:1]

# %%
y = df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3, random_state= 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47
# 137  7.14
# 163  8.93
# 111  5.42
# 123  5.10
# 109  7.77
# 141  6.76
# 41   6.89
# 130  6.68
# 140  7.91
# 5    7.89
# 159  8.71
# 100  7.95
# 11   6.61
# 187  6.26
# 24   6.53
# 89   6.42
# 66   5.11
# 8    6.09
# 172  6.93
# 175  7.04

# %%
y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# 137    3.13
# 163    3.91
# 111    2.25
# 123    2.30
# 109    4.06
# 141    3.18
# 41     2.70
# 130    2.49
# 140    3.15
# 5      2.99
# 159    4.08
# 100    4.14
# 11     2.60
# 187    2.44
# 24     2.71
# 89     2.72
# 66     1.63
# 8      2.31
# 172    2.51
# 175    3.50
# Name: package, dtype: float64

# %%
lr.predict(x_test.iloc[1].values.reshape(1,1))
# Out:
# C:\DataScience\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.09544039])

# %%
##   looking the pridicted line on training dataset

plt.scatter(df['cgpa'],df['package'])
plt.plot(x_train, lr.predict(x_train), c = 'red')
plt.xlabel("CGPA")
plt.ylabel("PACKAGE")
# Out:
# Text(0, 0.5, 'PACKAGE')

# %%
##  predicted line on test dataset

plt.scatter(x_test, y_test)
plt.plot(x_test, lr.predict(x_test), c='pink')
plt.xlabel("CGPA")
plt.ylabel("PACKAGE")
# Out:
# Text(0, 0.5, 'PACKAGE')

# %% [markdown]
# # how ml find the slope (y = mx + b)

# %%
m = lr.coef_
m
# Out:
# array([0.55574241])

# %%
b = lr.intercept_
b
# Out:
# np.float64(-0.8781178361812025)

# %%
# y = mx + b

# %%
# ml gives prediction of first student package
lr.predict(x_test.iloc[0].values.reshape(1,1))
# Out:
# C:\DataScience\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89015204])

# %%
## see how first student result comes 

y = (m * 8.58) + b
y
# Out:
# array([3.89015204])
